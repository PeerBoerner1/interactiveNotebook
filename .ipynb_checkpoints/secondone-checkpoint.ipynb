# %%
print("Hello cluster")
# Out:
# VBox()
# Starting Spark application

# %% [markdown]
# # Just some experiments with git hub saving

# %%
sc.list_packages()

# %%
# %info

# %%
# %%sh
# ping -c 5 www.google.com
