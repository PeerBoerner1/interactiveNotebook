# %%
print("Hello cluster")
# Out:
# VBox()
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>33</td><td>application_1655062366648_0003</td><td>pyspark</td><td>idle</td><td></td><td></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Hello cluster

# %% [markdown]
# ## Configure required libraries

# %%
# %matplotlib notebook
# %matplotlib inline

# %%
# %pip install ipympl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load some big data

# %%
import matplotlib
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Load the amazon book sample data source ~20 million rows
spdf = spark.read.parquet('s3://amazon-reviews-pds/parquet/product_category=Books/*.parquet')
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
spdf.printSchema()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- marketplace: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- product_parent: string (nullable = true)
#  |-- product_title: string (nullable = true)
#  |-- star_rating: integer (nullable = true)
#  |-- helpful_votes: integer (nullable = true)
#  |-- total_votes: integer (nullable = true)
#  |-- vine: string (nullable = true)
#  |-- verified_purchase: string (nullable = true)
#  |-- review_headline: string (nullable = true)
#  |-- review_body: string (nullable = true)
#  |-- review_date: date (nullable = true)
#  |-- year: integer (nullable = true)

# %%
# Grab a sub-set of all the fields
# Other analytic transformation would happen here as well.
votesDf=spdf.select('customer_id', 'review_date','product_title','star_rating', 'total_votes').sort('customer_id')
print(f"Number of rows in spark data frame: {votesDf.count():,}")
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Number of rows in spark data frame: 20,726,160

# %%
# %%spark -o votesDf
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %%local votesDf['review_date'].where(votesDf.review_date > '2014-07-12').count()
# Out:
# 847

# %%
# %%local
# from IPython.display import display
# from ipywidgets import Dropdown
# from ipywidgets import interact, interactive, fixed, interact_manual
# import ipywidgets as widgets
#
# def f(x):
#     return x
#
# interact(f, x=10);

# %% [markdown]
# # Just some experiments with git hub saving

# %%
import pandas
