# %%
print("Hello cluster")
# Out:
# VBox()
# Starting Spark application
# <table>
# <tbody><tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>31</td><td>application_1655062366648_0001</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-42-47.ec2.internal:20888/proxy/application_1655062366648_0001/" class="emr-proxy-link j-2CY4U2CHF7JNE application_1655062366648_0001" emr-resource="j-2CY4U2CHF7JNE
# " application-id="application_1655062366648_0001">Link</a></td><td><a target="_blank" href="http://ip-172-31-47-192.ec2.internal:8042/node/containerlogs/container_1655062366648_0001_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></tbody></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Hello cluster

# %% [markdown]
# ## Configure required libraries

# %%
# %matplotlib notebook
# %matplotlib inline

# %%
# %pip install ipympl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipympl
#   Downloading ipympl-0.9.1-py2.py3-none-any.whl (508 kB)
#      |████████████████████████████████| 508 kB 24.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /mnt/notebook-env/lib/python3.7/site-packages (from ipympl) (1.21.2)
# Requirement already satisfied: pillow in /mnt/notebook-env/lib/python3.7/site-packages (from ipympl) (8.4.0)
# Requirement already satisfied: ipython-genutils in /mnt/notebook-env/lib/python3.7/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: traitlets<6 in /mnt/notebook-env/lib/python3.7/site-packages (from ipympl) (5.1.1)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /home/emr-notebook/.local/lib/python3.7/site-packages (from ipympl) (3.5.2)
# Requirement already satisfied: ipywidgets<8,>=7.6.0 in /mnt/notebook-env/lib/python3.7/site-packages (from ipympl) (7.6.5)
# Requirement already satisfied: ipython<9 in /mnt/notebook-env/lib/python3.7/site-packages (from ipympl) (7.31.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /mnt/notebook-env/lib/python3.7/site-packages (from ipython<9->ipympl) (3.0.20)
# Requirement already satisfied: backcall in /mnt/notebook-env/lib/python3.7/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /mnt/notebook-env/lib/python3.7/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: pickleshare in /mnt/notebook-env/lib/python3.7/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: pygments in /mnt/notebook-env/lib/python3.7/site-packages (from ipython<9->ipympl) (2.11.2)
# Requirement already satisfied: matplotlib-inline in /mnt/notebook-env/lib/python3.7/site-packages (from ipython<9->ipympl) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in /mnt/notebook-env/lib/python3.7/site-packages (from ipython<9->ipympl) (58.0.4)
# Requirement already satisfied: decorator in /mnt/notebook-env/lib/python3.7/site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /mnt/notebook-env/lib/python3.7/site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /mnt/notebook-env/lib/python3.7/site-packages (from ipywidgets<8,>=7.6.0->ipympl) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /mnt/notebook-env/lib/python3.7/site-packages (from ipywidgets<8,>=7.6.0->ipympl) (5.3.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /mnt/notebook-env/lib/python3.7/site-packages (from ipywidgets<8,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /mnt/notebook-env/lib/python3.7/site-packages (from ipywidgets<8,>=7.6.0->ipympl) (5.1.3)
# Requirement already satisfied: jupyter-client in /mnt/notebook-env/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (6.1.3)
# Requirement already satisfied: tornado>=4.2 in /mnt/notebook-env/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /mnt/notebook-env/lib/python3.7/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/emr-notebook/.local/lib/python3.7/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.33.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/emr-notebook/.local/lib/python3.7/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /home/emr-notebook/.local/lib/python3.7/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /mnt/notebook-env/lib/python3.7/site-packages (from matplotlib<4,>=3.4.0->ipympl) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /mnt/notebook-env/lib/python3.7/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /mnt/notebook-env/lib/python3.7/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.4)
# Requirement already satisfied: typing-extensions in /mnt/notebook-env/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib<4,>=3.4.0->ipympl) (3.10.0.2)
# Requirement already satisfied: jupyter-core in /mnt/notebook-env/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (4.9.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /mnt/notebook-env/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (3.2.0)
# Requirement already satisfied: six>=1.11.0 in /mnt/notebook-env/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /mnt/notebook-env/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /mnt/notebook-env/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (21.4.0)
# Requirement already satisfied: importlib-metadata in /mnt/notebook-env/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (4.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /mnt/notebook-env/lib/python3.7/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /mnt/notebook-env/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /mnt/notebook-env/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (6.0.3)
# Requirement already satisfied: prometheus-client in /mnt/notebook-env/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.13.1)
# Requirement already satisfied: terminado>=0.8.1 in /mnt/notebook-env/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.13.1)
# Requirement already satisfied: Send2Trash in /mnt/notebook-env/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: nbconvert in /mnt/notebook-env/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (5.6.1)
# Requirement already satisfied: pyzmq>=17 in /mnt/notebook-env/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (22.3.0)
# Requirement already satisfied: jinja2 in /mnt/notebook-env/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (3.0.2)
# Requirement already satisfied: zipp>=0.5 in /mnt/notebook-env/lib/python3.7/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (3.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/notebook-env/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (2.0.1)
# Requirement already satisfied: defusedxml in /mnt/notebook-env/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: bleach in /mnt/notebook-env/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (4.1.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /mnt/notebook-env/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.3)
# Requirement already satisfied: testpath in /mnt/notebook-env/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /mnt/notebook-env/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /mnt/notebook-env/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: webencodings in /mnt/notebook-env/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.5.1)
# Installing collected packages: ipympl
# Successfully installed ipympl-0.9.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load some big data

# %%
# %%local
# from IPython.display import display
# from ipywidgets import Dropdown
# from ipywidgets import interact, interactive, fixed, interact_manual
# import ipywidgets as widgets
#
# def f(x):
#     return x
#
# interact(f, x=10);
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…

# %% [markdown]
# # Just some experiments with git hub saving

# %%
import pandas
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %%sh
# ping -c 5 www.google.com

# %%
import ipywidgets as w
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
w.Text("hello")
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Text(value='hello')

# %%
import matplotlib.pyplot as plt
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# An error was encountered:
# Matplotlib requires numpy>=1.17; you have 1.16.5
# Traceback (most recent call last):
#   File "/usr/local/lib64/python3.7/site-packages/matplotlib/__init__.py", line 208, in <module>
#     _check_versions()
#   File "/usr/local/lib64/python3.7/site-packages/matplotlib/__init__.py", line 204, in _check_versions
#     raise ImportError(f"Matplotlib requires {modname}>={minver}; "
# ImportError: Matplotlib requires numpy>=1.17; you have 1.16.5

# %%
w
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# <module 'ipywidgets' from '/usr/local/lib/python3.7/site-packages/ipywidgets/__init__.py'>

# %%
w.IntSlider(description='value')
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# IntSlider(value=0, description='value')

# %%
ipykernel import display
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# An error was encountered:
# invalid syntax (<stdin>, line 1)
#   File "<stdin>", line 1
#     ipykernel import display
#                    ^
# SyntaxError: invalid syntax
